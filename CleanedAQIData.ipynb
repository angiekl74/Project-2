# %%
# Import Dependencies
import pandas as pd
import datetime as dt
from sqlalchemy import create_engine
from config import password

# %%
# Create db in pgadmin if not already created
# Create postgres engine and connect

# engine = create_engine('postgresql://localhost:5432/Project2AQI')
# conn = engine.connect()

engine = create_engine(f"postgresql://postgres:{password}@localhost:5432/Project2AQI")
conn = engine.connect()

# %%
# LA - Import raw/uncleaned cvs files 
dataLA = pd.read_csv("Resources/aqiDailyLA.csv")

# %%
# View dataLA types
dataLA.head()
# Out:
#        Date  Overall_AQI_Value Main Pollutant      Site Name (of Overall AQI)  \
# 0  1/1/2020                102          PM2.5  Long Beach-Route 710 Near Road
# 1  1/2/2020                 66          PM2.5  Long Beach-Route 710 Near Road
# 2  1/3/2020                 87          PM2.5  Long Beach-Route 710 Near Road
# 3  1/4/2020                 99          PM2.5  Long Beach-Route 710 Near Road
# 4  1/5/2020                 96          PM2.5  Long Beach-Route 710 Near Road
#
#   Site ID (of Overall AQI) Source (of Overall AQI)  CO  Ozone  SO2  PM10  \
# 0              06-037-4008                  AirNow NaN     44  NaN   NaN
# 1              06-037-4008                  AirNow NaN     40  NaN   NaN
# 2              06-037-4008                  AirNow NaN     41  NaN   NaN
# 3              06-037-4008                  AirNow NaN     36  NaN   NaN
# 4              06-037-4008                  AirNow NaN     40  NaN   NaN
#
#    PM25  NO2
# 0   102  NaN
# 1    66  NaN
# 2    87  NaN
# 3    99  NaN
# 4    96  NaN

# %% [markdown]
# ### Cleaning all 10 csv files for each city

# %%
# Add latitude and longitude for LA
dataLA["lat"] = 34.0522
dataLA["lon"] = -118.2437

# Add City name
dataLA["city_name"] = "Los_Angeles"

# Add shelter in place date
dataLA["state_ordinance"] = "2020-03-23"

#Add population 
dataLA["population"] = int("3990456")

# Changed date colume from object to datetime
dataLA["Date"] = pd.to_datetime(dataLA["Date"])
dataLA["state_ordinance"] = pd.to_datetime(dataLA["state_ordinance"])

# Rename columns
dataLA = dataLA.rename(columns= {"Date": "date",
                                 "Overall_AQI_Value": "overall_aqi_value",
                                 "Main Pollutant": "main_pollutant",
                                 "Site Name (of Overall AQI)": "site_name",
                                 "Site ID (of Overall AQI)": "site_id",
                                 "Source (of Overall AQI)": "source_aqi",
                                 "CO": "co",
                                 "Ozone": "ozone",
                                 "SO2": "so2",
                                 "PM10": "pm10",
                                 "PM25": "pm25",
                                 "NO2": "no2"})

# %%
# Run head() and dtypes to check that changes took
dataLA.head()
# dataLA.dtypes
# Out:
#         date  overall_aqi_value main_pollutant  \
# 0 2020-01-01                102          PM2.5
# 1 2020-01-02                 66          PM2.5
# 2 2020-01-03                 87          PM2.5
# 3 2020-01-04                 99          PM2.5
# 4 2020-01-05                 96          PM2.5
#
#                         site_name      site_id source_aqi  co  ozone  so2  \
# 0  Long Beach-Route 710 Near Road  06-037-4008     AirNow NaN     44  NaN
# 1  Long Beach-Route 710 Near Road  06-037-4008     AirNow NaN     40  NaN
# 2  Long Beach-Route 710 Near Road  06-037-4008     AirNow NaN     41  NaN
# 3  Long Beach-Route 710 Near Road  06-037-4008     AirNow NaN     36  NaN
# 4  Long Beach-Route 710 Near Road  06-037-4008     AirNow NaN     40  NaN
#
#    pm10  pm25  no2      lat       lon    city_name state_ordinance  \
# 0   NaN   102  NaN  34.0522 -118.2437  Los_Angeles      2020-03-23
# 1   NaN    66  NaN  34.0522 -118.2437  Los_Angeles      2020-03-23
# 2   NaN    87  NaN  34.0522 -118.2437  Los_Angeles      2020-03-23
# 3   NaN    99  NaN  34.0522 -118.2437  Los_Angeles      2020-03-23
# 4   NaN    96  NaN  34.0522 -118.2437  Los_Angeles      2020-03-23
#
#    population        dob1
# 0     3990456  01/01/2020
# 1     3990456  01/02/2020
# 2     3990456  01/03/2020
# 3     3990456  01/04/2020
# 4     3990456  01/05/2020

# %%
# Import raw/uncleaned cvs files 
dataBoise = pd.read_csv("Resources/aqiDailyBoise.csv")
dataNewOrleans = pd.read_csv("Resources/aqiDailyNewOrleans.csv")
dataNY = pd.read_csv("Resources/aqiDailyNY.csv")
dataPortland = pd.read_csv("Resources/aqiDailyPortland.csv")
dataSeattle = pd.read_csv("Resources/aqiDailySeattle.csv")
dataMilwaukee = pd.read_csv("Resources/aqiDailyMilwaukee.csv")
dataIndianapolis = pd.read_csv("Resources/aqiDailyIndianapolis.csv")
dataDetroit = pd.read_csv("Resources/aqiDailyDetroit.csv")
dataColumbus= pd.read_csv("Resources/aqiDailyColumbus.csv")

# %%
dataBoise.head()
# Out:
#        Date  Overall_AQI_Value Main Pollutant     Site Name (of Overall AQI)  \
# 0  1/1/2020                 63          PM2.5  Boise - White Pine Elementary
# 1  1/2/2020                 62          PM2.5  Boise - White Pine Elementary
# 2  1/3/2020                 52          PM2.5  Boise - White Pine Elementary
# 3  1/4/2020                 55          PM2.5  Boise - White Pine Elementary
# 4  1/5/2020                 43          PM2.5  Boise - White Pine Elementary
#
#      Lat        Lon Site ID (of Overall AQI) Source (of Overall AQI)  CO  \
# 0  43.615 -116.2023              16-015-0001                  AirNow NaN
# 1  43.615 -116.2023              16-015-0001                  AirNow NaN
# 2  43.615 -116.2023              16-015-0001                  AirNow NaN
# 3  43.615 -116.2023              16-015-0001                  AirNow NaN
# 4  43.615 -116.2023              16-015-0001                  AirNow NaN
#
#   Ozone  SO2 PM10  PM25  NO2
# 0    28  NaN  NaN    63  NaN
# 1    23  NaN  NaN    62  NaN
# 2    26  NaN  NaN    52  NaN
# 3    28  NaN  NaN    55  NaN
# 4    24  NaN  NaN    43  NaN

# %%
# Add latitude and longitude for Boise
dataBoise["lat"] = 43.6150
dataBoise["lon"] = -116.2023
# Change name column value  
dataBoise["city_name"] = "Boise"
# Add state ordinance
dataBoise["state_ordinance"] = "2020-03-25"
#Add population 
dataBoise["population"] = int("228790")
# Changed date colume from object to datetime
dataBoise["Date"] = pd.to_datetime(dataBoise["Date"])
dataBoise["state_ordinance"] = pd.to_datetime(dataBoise["state_ordinance"])
dataBoise = dataBoise.rename(columns= {"Date": "date",
                                 "Overall_AQI_Value": "overall_aqi_value",
                                 "Main Pollutant": "main_pollutant",
                                 "Site Name (of Overall AQI)": "site_name",
                                 "Site ID (of Overall AQI)": "site_id",
                                 "Source (of Overall AQI)": "source_aqi",
                                 "CO": "co",
                                 "Ozone": "ozone",
                                 "SO2": "so2",
                                 "PM10": "pm10",
                                 "PM25": "pm25",
                                 "NO2": "no2"})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\pythondata\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-d70252ce85b3> in <module>
#       9 dataBoise["population"] = int("228790")
#      10 # Changed date colume from object to datetime
# ---> 11 dataBoise["Date"] = pd.to_datetime(dataBoise["Date"])
#      12 dataBoise["state_ordinance"] = pd.to_datetime(dataBoise["state_ordinance"])
#      13 dataBoise = dataBoise.rename(columns= {"Date": "date",
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'

# %%
dataBoise.head()
# Out:
#         date  overall_aqi_value main_pollutant                      site_name  \
# 0 2020-01-01                 63          PM2.5  Boise - White Pine Elementary
# 1 2020-01-02                 62          PM2.5  Boise - White Pine Elementary
# 2 2020-01-03                 52          PM2.5  Boise - White Pine Elementary
# 3 2020-01-04                 55          PM2.5  Boise - White Pine Elementary
# 4 2020-01-05                 43          PM2.5  Boise - White Pine Elementary
#
#      Lat        Lon      site_id source_aqi  co ozone  so2 pm10  pm25  no2  \
# 0  43.615 -116.2023  16-015-0001     AirNow NaN    28  NaN  NaN    63  NaN
# 1  43.615 -116.2023  16-015-0001     AirNow NaN    23  NaN  NaN    62  NaN
# 2  43.615 -116.2023  16-015-0001     AirNow NaN    26  NaN  NaN    52  NaN
# 3  43.615 -116.2023  16-015-0001     AirNow NaN    28  NaN  NaN    55  NaN
# 4  43.615 -116.2023  16-015-0001     AirNow NaN    24  NaN  NaN    43  NaN
#
#       lat       lon city_name state_ordinance  population
# 0  43.615 -116.2023     Boise      2020-03-25      228790
# 1  43.615 -116.2023     Boise      2020-03-25      228790
# 2  43.615 -116.2023     Boise      2020-03-25      228790
# 3  43.615 -116.2023     Boise      2020-03-25      228790
# 4  43.615 -116.2023     Boise      2020-03-25      228790

# %%
# Add latitude and longitude for Columbus
dataColumbus["lat"] = 39.9612
dataColumbus["lon"] = -82.9988
# RendataLAame column value  
dataColumbus["city_name"] = "Columbus"
# Add state ordinance
dataColumbus["state_ordinance"] = "2020-03-23"
#Add population 
dataColumbus["population"] = int("892533")
# Changed date colume from object to datetime
dataColumbus["Date"] = pd.to_datetime(dataColumbus["Date"])
dataColumbus["state_ordinance"] = pd.to_datetime(dataColumbus["state_ordinance"])

dataColumbus = dataColumbus.rename(columns= {"Date": "date",
                                 "Overall AQI Value": "overall_aqi_value",
                                 "Main Pollutant": "main_pollutant",
                                 "Site Name (of Overall AQI)": "site_name",
                                 "Site ID (of Overall AQI)": "site_id",
                                 "Source (of Overall AQI)": "source_aqi",
                                 "CO": "co",
                                 "Ozone": "ozone",
                                 "SO2": "so2",
                                 "PM10": "pm10",
                                 "PM25": "pm25",
                                 "NO2": "no2"})

# %%
# Add latitude and longitude for Detroit
dataDetroit["lat"] = 42.3314
dataDetroit["lon"] = -83.0458
# RendataLAame column value  
dataDetroit["city_name"] = "Detroit"
# Add state ordinance
dataDetroit["state_ordinance"] = "2020-03-24"
#Add population 
dataDetroit["population"] = int("672662")
# Changed date colume from object to datetime
dataDetroit["Date"] = pd.to_datetime(dataDetroit["Date"])
dataDetroit["state_ordinance"] = pd.to_datetime(dataDetroit["state_ordinance"])

dataDetroit = dataDetroit.rename(columns= {"Date": "date",
                                 "Overall AQI Value": "overall_aqi_value",
                                 "Main Pollutant": "main_pollutant",
                                 "Site Name (of Overall AQI)": "site_name",
                                 "Site ID (of Overall AQI)": "site_id",
                                 "Source (of Overall AQI)": "source_aqi",
                                 "CO": "co",
                                 "Ozone": "ozone",
                                 "SO2": "so2",
                                 "PM10": "pm10",
                                 "PM25": "pm25",
                                 "NO2": "no2"})

# %%
# Add latitude and longitude for Milwaukee
dataMilwaukee["lat"] = 43.0389
dataMilwaukee["lon"] = -87.9065
# RendataLAame column value  
dataMilwaukee["city_name"] = "Milwaukee"
# Add state ordinance
dataMilwaukee["state_ordinance"] = "2020-03-25"
#Add population 
dataMilwaukee["population"] = int("592025")
# Changed date colume from object to datetime
dataMilwaukee["Date"] = pd.to_datetime(dataMilwaukee["Date"])
dataMilwaukee["state_ordinance"] = pd.to_datetime(dataMilwaukee["state_ordinance"])

dataMilwaukee = dataMilwaukee.rename(columns= {"Date": "date",
                                 "Overall AQI Value": "overall_aqi_value",
                                 "Main Pollutant": "main_pollutant",
                                 "Site Name (of Overall AQI)": "site_name",
                                 "Site ID (of Overall AQI)": "site_id",
                                 "Source (of Overall AQI)": "source_aqi",
                                 "CO": "co",
                                 "Ozone": "ozone",
                                 "SO2": "so2",
                                 "PM10": "pm10",
                                 "PM25": "pm25",
                                 "NO2": "no2"})

# %%
dataColumbus.head()
# Out:
#         date  overall_aqi_value main_pollutant            site_name  \
# 0 2020-01-01                 24          PM2.5  Smoky Row Near Road
# 1 2020-01-02                 17          PM2.5  Smoky Row Near Road
# 2 2020-01-03                 23            NO2          Fairgrounds
# 3 2020-01-04                 40          PM2.5         Maple Canyon
# 4 2020-01-05                 24          PM2.5  Smoky Row Near Road
#
#        site_id source_aqi co ozone so2 pm10  pm25 no2      lat      lon  \
# 0  39-049-0038        AQS  0     .   0    .    24  10  39.9612 -82.9988
# 1  39-049-0038        AQS  1     .   0    .    17  15  39.9612 -82.9988
# 2  39-049-0034        AQS  2     .   0    .    18  23  39.9612 -82.9988
# 3  39-049-0081        AQS  0     .   0    7    40   7  39.9612 -82.9988
# 4  39-049-0038        AQS  0     .   0    .    24   9  39.9612 -82.9988
#
#   city_name state_ordinance  population
# 0  Columbus      2020-03-23      391006
# 1  Columbus      2020-03-23      391006
# 2  Columbus      2020-03-23      391006
# 3  Columbus      2020-03-23      391006
# 4  Columbus      2020-03-23      391006

# %%
# Add latitude and longitude for Columbus
dataColumbus["lat"] = 39.9612
dataColumbus["lon"] = -82.9988
# RendataLAame column value  
dataColumbus["city_name"] = "Columbus"
# Add state ordinance
dataColumbus["state_ordinance"] = "2020-03-23"
#Add population 
dataColumbus["population"] = int("391006")
# Changed date colume from object to datetime
dataColumbus["date"] = pd.to_datetime(dataColumbus["date"])
dataColumbus["state_ordinance"] = pd.to_datetime(dataColumbus["state_ordinance"])

dataColumbus = dataColumbus.rename(columns= {"date": "date",
                                 "Overall_AQI_Value": "overall_aqi_value",
                                 "Main Pollutant": "main_pollutant",
                                 "Site Name (of Overall AQI)": "site_name",
                                 "Site ID (of Overall AQI)": "site_id",
                                 "Source (of Overall AQI)": "source_aqi",
                                 "CO": "co",
                                 "Ozone": "ozone",
                                 "SO2": "so2",
                                 "PM10": "pm10",
                                 "PM25": "pm25",
                                 "NO2": "no2"})

# %%
dataColumbus.head()
# Out:
#         date  overall_aqi_value main_pollutant            site_name  \
# 0 2020-01-01                 24          PM2.5  Smoky Row Near Road
# 1 2020-01-02                 17          PM2.5  Smoky Row Near Road
# 2 2020-01-03                 23            NO2          Fairgrounds
# 3 2020-01-04                 40          PM2.5         Maple Canyon
# 4 2020-01-05                 24          PM2.5  Smoky Row Near Road
#
#        site_id source_aqi co ozone so2 pm10  pm25 no2      lat      lon  \
# 0  39-049-0038        AQS  0     .   0    .    24  10  39.9612 -82.9988
# 1  39-049-0038        AQS  1     .   0    .    17  15  39.9612 -82.9988
# 2  39-049-0034        AQS  2     .   0    .    18  23  39.9612 -82.9988
# 3  39-049-0081        AQS  0     .   0    7    40   7  39.9612 -82.9988
# 4  39-049-0038        AQS  0     .   0    .    24   9  39.9612 -82.9988
#
#   city_name state_ordinance  population
# 0  Columbus      2020-03-23      391006
# 1  Columbus      2020-03-23      391006
# 2  Columbus      2020-03-23      391006
# 3  Columbus      2020-03-23      391006
# 4  Columbus      2020-03-23      391006

# %%
dataDetroit.head()
# Out:
#         date  overall_aqi_value main_pollutant  \
# 0 2020-01-01                 55          PM2.5
# 1 2020-01-02                 49          PM2.5
# 2 2020-01-03                 58          PM2.5
# 3 2020-01-04                 32          PM2.5
# 4 2020-01-05                 53          PM2.5
#
#                                    site_name      site_id source_aqi  co  \
# 0                    TRINITY ST MARKS (GHIB)  26-163-0099     AirNow NaN
# 1  PROPERTY OWNED BY DEARBORN PUBLIC SCHOOLS  26-163-0033     AirNow NaN
# 2                    TRINITY ST MARKS (GHIB)  26-163-0099     AirNow NaN
# 3                    TRINITY ST MARKS (GHIB)  26-163-0099     AirNow NaN
# 4                       Military Park (GHIB)  26-163-0100     AirNow NaN
#
#   ozone  so2  pm10  pm25  no2      lat      lon city_name state_ordinance  \
# 0    29  NaN   NaN    55  NaN  42.3314 -83.0458   Detroit      2020-03-24
# 1    26  NaN   NaN    49  NaN  42.3314 -83.0458   Detroit      2020-03-24
# 2    19  NaN   NaN    58  NaN  42.3314 -83.0458   Detroit      2020-03-24
# 3    31  NaN   NaN    32  NaN  42.3314 -83.0458   Detroit      2020-03-24
# 4    31  NaN   NaN    53  NaN  42.3314 -83.0458   Detroit      2020-03-24
#
#    population
# 0      672662
# 1      672662
# 2      672662
# 3      672662
# 4      672662

# %%
# Add latitude and longitude for Detroit
dataDetroit["lat"] = 42.3314
dataDetroit["lon"] = -83.0458
# RendataLAame column value  
dataDetroit["city_name"] = "Detroit"
# Add state ordinance
dataDetroit["state_ordinance"] = "2020-03-24"
# Changed date colume from object to datetime
dataDetroit["date"] = pd.to_datetime(dataDetroit["date"])
dataDetroit["state_ordinance"] = pd.to_datetime(dataDetroit["state_ordinance"])

dataDetroit = dataDetroit.rename(columns= {"date": "date",
                                 "Overall AQI Value": "overall_aqi_value",
                                 "Main Pollutant": "main_pollutant",
                                 "Site Name (of Overall AQI)": "site_name",
                                 "Site ID (of Overall AQI)": "site_id",
                                 "Source (of Overall AQI)": "source_aqi",
                                 "CO": "co",
                                 "Ozone": "ozone",
                                 "SO2": "so2",
                                 "PM10": "pm10",
                                 "PM25": "pm25",
                                 "NO2": "no2"})

# %%
dataDetroit.head()
# Out:
#         date  overall_aqi_value main_pollutant  \
# 0 2020-01-01                 55          PM2.5
# 1 2020-01-02                 49          PM2.5
# 2 2020-01-03                 58          PM2.5
# 3 2020-01-04                 32          PM2.5
# 4 2020-01-05                 53          PM2.5
#
#                                    site_name      site_id source_aqi  co  \
# 0                    TRINITY ST MARKS (GHIB)  26-163-0099     AirNow NaN
# 1  PROPERTY OWNED BY DEARBORN PUBLIC SCHOOLS  26-163-0033     AirNow NaN
# 2                    TRINITY ST MARKS (GHIB)  26-163-0099     AirNow NaN
# 3                    TRINITY ST MARKS (GHIB)  26-163-0099     AirNow NaN
# 4                       Military Park (GHIB)  26-163-0100     AirNow NaN
#
#   ozone  so2  pm10  pm25  no2      lat      lon city_name state_ordinance  \
# 0    29  NaN   NaN    55  NaN  42.3314 -83.0458   Detroit      2020-03-24
# 1    26  NaN   NaN    49  NaN  42.3314 -83.0458   Detroit      2020-03-24
# 2    19  NaN   NaN    58  NaN  42.3314 -83.0458   Detroit      2020-03-24
# 3    31  NaN   NaN    32  NaN  42.3314 -83.0458   Detroit      2020-03-24
# 4    31  NaN   NaN    53  NaN  42.3314 -83.0458   Detroit      2020-03-24
#
#    population
# 0      672662
# 1      672662
# 2      672662
# 3      672662
# 4      672662

# %%
dataMilwaukee.head()
# Out:
#         date  overall_aqi_value main_pollutant  \
# 0 2020-01-01                 35          PM2.5
# 1 2020-01-02                 29          PM2.5
# 2 2020-01-03                 43          PM2.5
# 3 2020-01-04                 31          Ozone
# 4 2020-01-05                 36          PM2.5
#
#                                  site_name      site_id source_aqi   co ozone  \
# 0  MILWAUKEE - SIXTEENTH ST. HEALTH CENTER  55-079-0010     AirNow  NaN    27
# 1                 WAUKESHA - CLEVELAND AVE  55-133-0027     AirNow  NaN    24
# 2  MILWAUKEE - SIXTEENTH ST. HEALTH CENTER  55-079-0010     AirNow  NaN    26
# 3                MILWAUKEE - SER DNR HDQRS  55-079-0026     AirNow  NaN    31
# 4  MILWAUKEE - SIXTEENTH ST. HEALTH CENTER  55-079-0010     AirNow  NaN    29
#
#    so2  pm10  pm25  no2      lat      lon  city_name state_ordinance  \
# 0  NaN   NaN    35  NaN  43.0389 -87.9065  Milwaukee      2020-03-25
# 1  NaN   NaN    29  NaN  43.0389 -87.9065  Milwaukee      2020-03-25
# 2  NaN   NaN    43  NaN  43.0389 -87.9065  Milwaukee      2020-03-25
# 3  NaN   NaN    30  NaN  43.0389 -87.9065  Milwaukee      2020-03-25
# 4  NaN   NaN    36  NaN  43.0389 -87.9065  Milwaukee      2020-03-25
#
#    population
# 0      592025
# 1      592025
# 2      592025
# 3      592025
# 4      592025

# %%
# Add latitude and longitude for Milwaukee
dataMilwaukee["lat"] = 43.0389
dataMilwaukee["lon"] = -87.9065
# RendataLAame column value  
dataMilwaukee["city_name"] = "Milwaukee"
# Add state ordinance
dataMilwaukee["state_ordinance"] = "2020-03-25"
# Changed date colume from object to datetime
dataMilwaukee["date"] = pd.to_datetime(dataMilwaukee["date"])
dataMilwaukee["state_ordinance"] = pd.to_datetime(dataMilwaukee["state_ordinance"])

dataMilwaukee = dataMilwaukee.rename(columns= {"date": "date",
                                 "Overall AQI Value": "overall_aqi_value",
                                 "Main Pollutant": "main_pollutant",
                                 "Site Name (of Overall AQI)": "site_name",
                                 "Site ID (of Overall AQI)": "site_id",
                                 "Source (of Overall AQI)": "source_aqi",
                                 "CO": "co",
                                 "Ozone": "ozone",
                                 "SO2": "so2",
                                 "PM10": "pm10",
                                 "PM25": "pm25",
                                 "NO2": "no2"})

# %%
dataMilwaukee.head()
# Out:
#         date  overall_aqi_value main_pollutant  \
# 0 2020-01-01                 35          PM2.5
# 1 2020-01-02                 29          PM2.5
# 2 2020-01-03                 43          PM2.5
# 3 2020-01-04                 31          Ozone
# 4 2020-01-05                 36          PM2.5
#
#                                  site_name      site_id source_aqi   co ozone  \
# 0  MILWAUKEE - SIXTEENTH ST. HEALTH CENTER  55-079-0010     AirNow  NaN    27
# 1                 WAUKESHA - CLEVELAND AVE  55-133-0027     AirNow  NaN    24
# 2  MILWAUKEE - SIXTEENTH ST. HEALTH CENTER  55-079-0010     AirNow  NaN    26
# 3                MILWAUKEE - SER DNR HDQRS  55-079-0026     AirNow  NaN    31
# 4  MILWAUKEE - SIXTEENTH ST. HEALTH CENTER  55-079-0010     AirNow  NaN    29
#
#    so2  pm10  pm25  no2      lat      lon  city_name state_ordinance  \
# 0  NaN   NaN    35  NaN  43.0389 -87.9065  Milwaukee      2020-03-25
# 1  NaN   NaN    29  NaN  43.0389 -87.9065  Milwaukee      2020-03-25
# 2  NaN   NaN    43  NaN  43.0389 -87.9065  Milwaukee      2020-03-25
# 3  NaN   NaN    30  NaN  43.0389 -87.9065  Milwaukee      2020-03-25
# 4  NaN   NaN    36  NaN  43.0389 -87.9065  Milwaukee      2020-03-25
#
#    population
# 0      592025
# 1      592025
# 2      592025
# 3      592025
# 4      592025

# %%
dataNewOrleans.head()
# Out:
#        Date  Overall_AQI_Value Main Pollutant Site Name (of Overall AQI)  \
# 0  1/1/2020                 84          PM2.5            Chalmette Vista
# 1  1/2/2020                 51          PM2.5            Chalmette Vista
# 2  1/3/2020                 36            SO2                      Norco
# 3  1/4/2020                 34          Ozone                     Kenner
# 4  1/5/2020                 34          Ozone                    Convent
#
#   Site ID (of Overall AQI) Source (of Overall AQI)  CO  Ozone SO2 PM10  PM25  \
# 0              22-087-0007                     AQS   6     34  37   49    84
# 1              22-087-0007                     AQS   5     31  50   19    51
# 2              22-089-0006                     AQS   6     35  36    4    10
# 3              22-051-1001                     AQS   6     34   3   12    24
# 4              22-093-0002                     AQS  10     34  27   10    30
#
#   NO2 state_ordinance  population
# 0  36      2020-03-23      391006
# 1  13      2020-03-23      391006
# 2  20      2020-03-23      391006
# 3  25      2020-03-23      391006
# 4  24      2020-03-23      391006

# %%
# Add latitude and longitude for NewOrleans
dataNewOrleans["lat"] = 29.9511
dataNewOrleans["lon"] = -90.0715
# RendataLAame column value  
dataNewOrleans["city_name"] = "New_Orleans"
# Add state ordinance
dataNewOrleans["state_ordinance"] = "2020-03-23"
# Changed date colume from object to datetime
dataNewOrleans["Date"] = pd.to_datetime(dataNewOrleans["Date"])
dataNewOrleans["state_ordinance"] = pd.to_datetime(dataNewOrleans["state_ordinance"])

dataNewOrleans = dataNewOrleans.rename(columns= {"Date": "date",
                                 "Overall_AQI_Value": "overall_aqi_value",
                                 "Main Pollutant": "main_pollutant",
                                 "Site Name (of Overall AQI)": "site_name",
                                 "Site ID (of Overall AQI)": "site_id",
                                 "Source (of Overall AQI)": "source_aqi",
                                 "CO": "co",
                                 "Ozone": "ozone",
                                 "SO2": "so2",
                                 "PM10": "pm10",
                                 "PM25": "pm25",
                                 "NO2": "no2"})

# %%
dataNewOrleans.head()
# Out:
#         date  overall_aqi_value main_pollutant        site_name      site_id  \
# 0 2020-01-01                 84          PM2.5  Chalmette Vista  22-087-0007
# 1 2020-01-02                 51          PM2.5  Chalmette Vista  22-087-0007
# 2 2020-01-03                 36            SO2            Norco  22-089-0006
# 3 2020-01-04                 34          Ozone           Kenner  22-051-1001
# 4 2020-01-05                 34          Ozone          Convent  22-093-0002
#
#   source_aqi  co  ozone so2 pm10  pm25 no2 state_ordinance  population  \
# 0        AQS   6     34  37   49    84  36      2020-03-23      391006
# 1        AQS   5     31  50   19    51  13      2020-03-23      391006
# 2        AQS   6     35  36    4    10  20      2020-03-23      391006
# 3        AQS   6     34   3   12    24  25      2020-03-23      391006
# 4        AQS  10     34  27   10    30  24      2020-03-23      391006
#
#        lat      lon    city_name
# 0  29.9511 -90.0715  New_Orleans
# 1  29.9511 -90.0715  New_Orleans
# 2  29.9511 -90.0715  New_Orleans
# 3  29.9511 -90.0715  New_Orleans
# 4  29.9511 -90.0715  New_Orleans

# %%
dataNY.head()
# Out:
#        Date  Overall_AQI_Value Main Pollutant Site Name (of Overall AQI)  \
# 0  1/1/2020                 36          PM2.5    Intermediate School 143
# 1  1/2/2020                 56          PM2.5    Intermediate School 143
# 2  1/3/2020                 68          PM2.5         Fort Lee Near Road
# 3  1/4/2020                 59          PM2.5         Fort Lee Near Road
# 4  1/5/2020                 37          PM2.5                       CCNY
#
#   Site ID (of Overall AQI) Source (of Overall AQI)  CO  Ozone SO2 PM10  PM25  \
# 0              36-061-0115                     AQS   2     31   0    .    36
# 1              36-061-0115                     AQS  13     31   9    .    56
# 2              34-003-0010                  AirNow  13     19   1    .    68
# 3              34-003-0010                  AirNow   8     28   1    .    59
# 4              36-061-0135                     AQS   6     33   0    .    37
#
#   NO2
# 0  17
# 1  39
# 2  36
# 3  28
# 4  19

# %%
# Add latitude and longitude for NY
dataNY["lat"] = 40.7128
dataNY["lon"] = -74.0060
# RendataLAame column value  
dataNY["city_name"] = "New_York"
# Add state ordinance
dataNY["state_ordinance"] = "2020-03-23"
# Changed date colume from object to datetime
dataNY["Date"] = pd.to_datetime(dataNY["Date"])
dataNY["state_ordinance"] = pd.to_datetime(dataNY["state_ordinance"])

dataNY = dataNY.rename(columns= {"Date": "date",
                                 "Overall_AQI_Value": "overall_aqi_value",
                                 "Main Pollutant": "main_pollutant",
                                 "Site Name (of Overall AQI)": "site_name",
                                 "Site ID (of Overall AQI)": "site_id",
                                 "Source (of Overall AQI)": "source_aqi",
                                 "CO": "co",
                                 "Ozone": "ozone",
                                 "SO2": "so2",
                                 "PM10": "pm10",
                                 "PM25": "pm25",
                                 "NO2": "no2"})

# %%
dataNY.head()
# Out:
#         date  overall_aqi_value main_pollutant                site_name  \
# 0 2020-01-01                 36          PM2.5  Intermediate School 143
# 1 2020-01-02                 56          PM2.5  Intermediate School 143
# 2 2020-01-03                 68          PM2.5       Fort Lee Near Road
# 3 2020-01-04                 59          PM2.5       Fort Lee Near Road
# 4 2020-01-05                 37          PM2.5                     CCNY
#
#        site_id source_aqi  co  ozone so2 pm10  pm25 no2      lat     lon  \
# 0  36-061-0115        AQS   2     31   0    .    36  17  40.7128 -74.006
# 1  36-061-0115        AQS  13     31   9    .    56  39  40.7128 -74.006
# 2  34-003-0010     AirNow  13     19   1    .    68  36  40.7128 -74.006
# 3  34-003-0010     AirNow   8     28   1    .    59  28  40.7128 -74.006
# 4  36-061-0135        AQS   6     33   0    .    37  19  40.7128 -74.006
#
#   city_name state_ordinance
# 0  New_York      2020-03-23
# 1  New_York      2020-03-23
# 2  New_York      2020-03-23
# 3  New_York      2020-03-23
# 4  New_York      2020-03-23

# %%
dataPortland.head()
# Out:
#        Date  Overall_AQI_Value Main Pollutant SiteName (of Overall AQI)  \
# 0  1/1/2020                 29          Ozone                  Portland
# 1  1/2/2020                 28          Ozone                  Portland
# 2  1/3/2020                 35          Ozone                  Portland
# 3  1/4/2020                 34          Ozone                  Portland
# 4  1/5/2020                 31          Ozone                  Portland
#
#   Site ID (of Overall AQI) Source (of Overall AQI)  CO  Ozone  SO2 PM10  PM25  \
# 0              41-051-0080                  AirNow NaN     29  NaN  NaN    16
# 1              41-051-0080                  AirNow NaN     28  NaN  NaN    20
# 2              41-051-0080                  AirNow NaN     35  NaN  NaN    20
# 3              41-051-0080                  AirNow NaN     34  NaN  NaN    20
# 4              41-051-0080                  AirNow NaN     31  NaN  NaN    15
#
#    NO2
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %%
# Add latitude and longitude for Portland
dataPortland["lat"] = 45.5051
dataPortland["lon"] = -122.6750
# RendataLAame column value  
dataPortland["city_name"] = "Portland"
# Add state ordinance
dataPortland["state_ordinance"] = "2020-03-23"
# Changed date colume from object to datetime
dataPortland["Date"] = pd.to_datetime(dataPortland["Date"])
dataPortland["state_ordinance"] = pd.to_datetime(dataPortland["state_ordinance"])

dataPortland = dataPortland.rename(columns= {"Date": "date",
                                 "Overall_AQI_Value": "overall_aqi_value",
                                 "Main Pollutant": "main_pollutant",
                                 "SiteName (of Overall AQI)": "site_name",
                                 "Site ID (of Overall AQI)": "site_id",
                                 "Source (of Overall AQI)": "source_aqi",
                                 "CO": "co",
                                 "Ozone": "ozone",
                                 "SO2": "so2",
                                 "PM10": "pm10",
                                 "PM25": "pm25",
                                 "NO2": "no2"})

# %%
dataNY.head()
# Out:
#         date  overall_aqi_value main_pollutant                site_name  \
# 0 2020-01-01                 36          PM2.5  Intermediate School 143
# 1 2020-01-02                 56          PM2.5  Intermediate School 143
# 2 2020-01-03                 68          PM2.5       Fort Lee Near Road
# 3 2020-01-04                 59          PM2.5       Fort Lee Near Road
# 4 2020-01-05                 37          PM2.5                     CCNY
#
#        site_id source_aqi  co  ozone so2 pm10  pm25 no2      lat     lon  \
# 0  36-061-0115        AQS   2     31   0    .    36  17  40.7128 -74.006
# 1  36-061-0115        AQS  13     31   9    .    56  39  40.7128 -74.006
# 2  34-003-0010     AirNow  13     19   1    .    68  36  40.7128 -74.006
# 3  34-003-0010     AirNow   8     28   1    .    59  28  40.7128 -74.006
# 4  36-061-0135        AQS   6     33   0    .    37  19  40.7128 -74.006
#
#   city_name state_ordinance  population
# 0  New_York      2020-03-23     8398748
# 1  New_York      2020-03-23     8398748
# 2  New_York      2020-03-23     8398748
# 3  New_York      2020-03-23     8398748
# 4  New_York      2020-03-23     8398748

# %%
# Add latitude and longitude for NY
dataNY["lat"] = 40.7128
dataNY["lon"] = -74.0060
# RendataLAame column value  
dataNY["city_name"] = "New_York"
# Add state ordinance
dataNY["state_ordinance"] = "2020-03-23"
#Add population 
dataNY["population"] = int("8398748")
# Changed date colume from object to datetime
dataNY["date"] = pd.to_datetime(dataNY["date"])
dataNY["state_ordinance"] = pd.to_datetime(dataNY["state_ordinance"])

dataNY = dataNY.rename(columns= {"date": "date",
                                 "Overall_AQI_Value": "overall_aqi_value",
                                 "Main Pollutant": "main_pollutant",
                                 "Site Name (of Overall AQI)": "site_name",
                                 "Site ID (of Overall AQI)": "site_id",
                                 "Source (of Overall AQI)": "source_aqi",
                                 "CO": "co",
                                 "Ozone": "ozone",
                                 "SO2": "so2",
                                 "PM10": "pm10",
                                 "PM25": "pm25",
                                 "NO2": "no2"})

# %%
# Add latitude and longitude for Portland
dataPortland["lat"] = 45.5051
dataPortland["lon"] = -122.6750
# RendataLAame column value  
dataPortland["city_name"] = "Portland"
# Add state ordinance
dataPortland["state_ordinance"] = "2020-03-23"
#Add population 
dataPortland["population"] = int("653115")
# Changed date colume from object to datetime
dataPortland["date"] = pd.to_datetime(dataPortland["date"])
dataPortland["state_ordinance"] = pd.to_datetime(dataPortland["state_ordinance"])

dataPortland = dataPortland.rename(columns= {"date": "date",
                                 "Overall_AQI_Value": "overall_aqi_value",
                                 "Main Pollutant": "main_pollutant",
                                 "SiteName (of Overall AQI)": "site_name",
                                 "Site ID (of Overall AQI)": "site_id",
                                 "Source (of Overall AQI)": "source_aqi",
                                 "CO": "co",
                                 "Ozone": "ozone",
                                 "SO2": "so2",
                                 "PM10": "pm10",
                                 "PM25": "pm25",
                                 "NO2": "no2"})

# %%
# Add latitude and longitude for Seattle
dataSeattle["lat"] = 47.6062
dataSeattle["lon"] = -122.3321
# RendataLAame column value  
dataSeattle["city_name"] = "Seattle"
# Add state ordinance
dataSeattle["state_ordinance"] = "2020-03-23"
#Add population 
dataSeattle["population"] = int("744955")
# Changed date colume from object to datetime
dataSeattle["Date"] = pd.to_datetime(dataSeattle["Date"])
dataSeattle["state_ordinance"] = pd.to_datetime(dataSeattle["state_ordinance"])

dataSeattle = dataSeattle.rename(columns= {"Date": "date",
                                 "Overall_AQI_Value": "overall_aqi_value",
                                 "Main Pollutant": "main_pollutant",
                                 "Site Name (of Overall AQI)": "site_name",
                                 "Site ID (of Overall AQI)": "site_id",
                                 "Source (of Overall AQI)": "source_aqi",
                                 "CO": "co",
                                 "Ozone": "ozone",
                                 "SO2": "so2",
                                 "PM10": "pm10",
                                 "PM25": "pm25",
                                 "NO2": "no2"})

# %%
# Add latitude and longitude for Indianapolis
dataIndianapolis["lat"] = 39.7684
dataIndianapolis["lon"] = -86.1581
# RendataLAame column value  
dataIndianapolis["city_name"] = "Indianapolis"
# Add state ordinance
dataIndianapolis["state_ordinance"] = "2020-03-24"
#Add population 
dataIndianapolis["population"] = int("867125")
# Changed date colume from object to datetime
dataIndianapolis["Date"] = pd.to_datetime(dataIndianapolis["Date"])
dataIndianapolis["state_ordinance"] = pd.to_datetime(dataIndianapolis["state_ordinance"])

dataIndianapolis = dataIndianapolis.rename(columns= {"Date": "date",
                                 "Overall AQI Value": "overall_aqi_value",
                                 "Main Pollutant": "main_pollutant",
                                 "Site Name (of Overall AQI)": "site_name",
                                 "Site ID (of Overall AQI)": "site_id",
                                 "Source (of Overall AQI)": "source_aqi",
                                 "CO": "co",
                                 "Ozone": "ozone",
                                 "SO2": "so2",
                                 "PM10": "pm10",
                                 "PM25": "pm25",
                                 "NO2": "no2"})

# %%
# To load to postgreSQL and add date as PK to each table
dataLA.to_sql("la", con=conn, if_exists="replace", index=False)
with engine.connect() as con:
    con.execute("ALTER TABLE la ADD PRIMARY KEY (date);")
    
dataBoise.to_sql("boise", con=conn, if_exists="replace", index=False)
with engine.connect() as con:
    con.execute("ALTER TABLE boise ADD PRIMARY KEY (date);")
    
dataColumbus.to_sql("columbus", con=conn, if_exists="replace", index=False)
with engine.connect() as con:
    con.execute("ALTER TABLE columbus ADD PRIMARY KEY (date);")
    
dataDetroit.to_sql("detroit", con=conn, if_exists="replace", index=False)
with engine.connect() as con:
    con.execute("ALTER TABLE detroit ADD PRIMARY KEY (date);")

dataMilwaukee.to_sql("milwaukee", con=conn, if_exists="replace", index=False)
with engine.connect() as con:
    con.execute("ALTER TABLE milwaukee ADD PRIMARY KEY (date);")
    
dataNewOrleans.to_sql("neworleans", con=conn, if_exists="replace", index=False)
with engine.connect() as con:
    con.execute("ALTER TABLE neworleans ADD PRIMARY KEY (date);")
    
dataNY.to_sql("ny", con=conn, if_exists="replace", index=False)
with engine.connect() as con:
    con.execute("ALTER TABLE ny ADD PRIMARY KEY (date);")
    
dataPortland.to_sql("portland", con=conn, if_exists="replace", index=False)
with engine.connect() as con:
    con.execute("ALTER TABLE portland ADD PRIMARY KEY (date);")
    
dataSeattle.to_sql("seattle", con=conn, if_exists="replace", index=False)
with engine.connect() as con:
    con.execute("ALTER TABLE seattle ADD PRIMARY KEY (date);")
    
dataIndianapolis.to_sql("indianapolis", con=conn, if_exists="replace", index=False)
with engine.connect() as con:
    con.execute("ALTER TABLE indianapolis ADD PRIMARY KEY (date);")

# %%
dataLA.to_csv("Resources/UpdatedLA.csv")
dataBoise.to_csv("Resources/UpdatedBoise.csv")
dataColumbus.to_csv("Resources/UpdatedColumbus.csv")
dataDetroit.to_csv("Resources/UpdatedDetroit.csv")
dataMilwaukee.to_csv("Resources/UpdatedMilwaukee.csv")
dataNewOrleans.to_csv("Resources/UpdatedNewOrleans.csv")
dataNY.to_csv("Resources/UpdatedNY.csv")
dataPortland.to_csv("Resources/UpdatedPortland.csv")
dataSeattle.to_csv("Resources/UpdatedSeattle.csv")
dataIndianapolis.to_csv("Resources/UpdatedIndianapolis.csv")
